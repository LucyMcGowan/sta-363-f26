# %% [markdown]
# # Colab 0: Getting used to the tools
#
# **STA 363 | Meeting 1**
#
# This is the first notebook you will touch in this course. There is nothing to
# get right or wrong here, only five things to do once so they are familiar
# later: write markdown, add a code cell, run code, import a package, and
# render a notebook to HTML.
#
# Work through the cells below in order, running each one with **Shift +
# Enter**. When you are done, go back to the **Application exercise 1** page
# and answer the question there.

# %% [markdown]
# ## Task 1: Markdown
#
# Every cell in a notebook is either **code** or **markdown**. This cell is a
# markdown cell: it holds text, not something that runs.
#
# Double-click this cell to open it for editing, then replace *your answer
# here* below with one sentence about what you are hoping to get out of this
# course. Run the cell (**Shift + Enter**) to render it back to formatted
# text.
#
# **Q:** What are you hoping to get out of this course? *your answer here*

# %% [markdown]
# ## Task 2: Code cells
#
# Use the **+ Code** button (menu bar, or hover between cells) to add a new
# code cell directly below this one. In it, write one line of Python that does
# simple arithmetic, then run it with **Shift + Enter**. The result appears
# right underneath the cell.

# %%
# your arithmetic here

# %% [markdown]
# ## Task 3: Importing a package
#
# Nearly every notebook in this course starts by importing packages, then
# reading in data from this course's GitHub repository with the same `DATA`
# pattern. Run the cell below.

# %%
import pandas as pd

DATA = "https://raw.githubusercontent.com/LucyMcGowan/sta-363-f26/main/data/"
Auto = pd.read_csv(DATA + "Auto.csv")
Auto.head()

# %% [markdown]
# ## Task 4: Rendering to HTML
#
# Every slide deck and every exercise in this course is a plain text file that
# gets **rendered** into the page you read. Notebooks render the same way. The
# cell below fetches a fresh copy of this same notebook from GitHub (the
# pristine starting version, not your edited one, so this always works the
# same way for everyone), converts it to an HTML page with a tool called
# `nbconvert`, and downloads that HTML file to your computer.
#
# Run it, then open the file that downloads. Later in the course, this is
# exactly how your own edited work turns into the pages you submit.

# %%
# !wget -q https://raw.githubusercontent.com/LucyMcGowan/sta-363-f26/main/ps/00-ps.ipynb
# !jupyter nbconvert --to html 00-ps.ipynb

from google.colab import files
files.download("00-ps.html")

# %% [markdown]
# ## Done
#
# Save your work so it does not disappear when this session ends: **File >
# Save a copy in Drive**.
#
# Go back to the **Application exercise 1** page and answer the question
# there.
